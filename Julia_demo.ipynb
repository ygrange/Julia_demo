# %% [markdown]
# # Demonstration notebook Technolunch YG

# %% [markdown]
# This notebook has been tested withthe following version of Julia

# %%
VERSION
# Out:
# v"0.4.2"

# %% [markdown]
# Short hand functions and implicit multiplication are nice features of Julia that make the code more readable to mathematicians:

# %%
f(x) = 2x+4
f(2)
# Out:
# 8

# %% [markdown]
# The ans variable, known to users of several math tools/languages:

# %%
ans + 2
# Out:
# 10

# %% [markdown]
# To get unicode characters: type type the LaTeX version and press tab (the following cell is the only one I will not execute to let you press tab yourself six times):

# %%
\Delta = 3
\alpha = 2
\Gamma = 3 * \alpha + 2*\pi + \Delta

# %% [markdown]
# I, for example, am always confused by less than or equal operators. Should I use <= or =<? And >= =>? Fancy Unicode support to the rescue!

# %%
1≤1
# Out:
# true

# %% [markdown]
# The @which macro is cool. It tells you where the function definition comes from (and in notebooks it is even cooler; click the link!):

# %%
@which 3 + 2
# Out:
# +(x::Int64, y::Int64) at int.jl:8

# %%
@which 3.+2.
# Out:
# .+(x::Number, y::Number) at operators.jl:117

# %%
# Pkg.add("Units")
using SIUnits
@which (1Newton + 2Newton)
# Out:
# +{T,S,m,kg,s,A,K,mol,cd,rad,sr}(x::SIUnits.SIQuantity{T,m,kg,s,A,K,mol,cd,rad,sr}, y::SIUnits.SIQuantity{S,m,kg,s,A,K,mol,cd,rad,sr}) at /Users/grange/.julia/v0.4/SIUnits/src/SIUnits.jl:176

# %%
methods(+)
# Out:
# # 174 methods for generic function "+":
# +(x::Bool) at bool.jl:33
# +(x::Bool, y::Bool) at bool.jl:36
# +(y::AbstractFloat, x::Bool) at bool.jl:46
# +(x::Int64, y::Int64) at int.jl:8
# +(x::Int8, y::Int8) at int.jl:16
# +(x::UInt8, y::UInt8) at int.jl:16
# +(x::Int16, y::Int16) at int.jl:16
# +(x::UInt16, y::UInt16) at int.jl:16
# +(x::Int32, y::Int32) at int.jl:16
# +(x::UInt32, y::UInt32) at int.jl:16
# +(x::UInt64, y::UInt64) at int.jl:16
# +(x::Int128, y::Int128) at int.jl:16
# +(x::UInt128, y::UInt128) at int.jl:16
# +(x::Integer, y::Ptr{T}) at pointer.jl:77
# +(x::Float32, y::Float32) at float.jl:203
# +(x::Float64, y::Float64) at float.jl:204
# +(z::Complex{T<:Real}, w::Complex{T<:Real}) at complex.jl:111
# +(x::Bool, z::Complex{Bool}) at complex.jl:118
# +(z::Complex{Bool}, x::Bool) at complex.jl:119
# +(x::Bool, z::Complex{T<:Real}) at complex.jl:125
# +(z::Complex{T<:Real}, x::Bool) at complex.jl:126
# +(x::Real, z::Complex{Bool}) at complex.jl:132
# ...

# %% [markdown]
# One feature I really like about Python is docstrings. Julia's take on this:

# %%
"""This function multiplies x by 3 and adds 2"""
f(x) = 2x + 3;

# %%
?f
# Out:
# search:
# This function multiplies x by 3 and adds 2

# %%
"""A function that says hello!"""
function sayHello()
       println("HELLO")
end
# Out:
# f fd for fma fld fft full find filt fill fft! fdio frexp foldr foldl
# sayHello (generic function with 1 method)

# %%
?sayHello
# Out:
# search:
# A function that says hello!

# %%
function sayBye()
    println("BYE")
end
# Out:
# sayBye (generic function with 1 method)
# sayHello

# %%
?sayBye
# Out:
# No documentation found.
#
# `sayBye` is a generic `Function`.
#
# ```julia
# # 1 method for generic function "sayBye":
# sayBye() at In[13]:2
# ```
# search: sayBye

# %%
@doc "This function will say bye!" -> sayBye

# %%
?sayBye
# Out:
# search:
# This function will say bye!
# sayBye

# %% [markdown]
# ## Modules
# Just a short intro into modules. Consider the following file:

# %%
;cat mymodule.jl
# Out:
# module mymodule
# export mycoolfunction
#
# function mycoolfunction()
#    println("this is my cool function")
# end
#
# function mysecretfunction()
#    println("this is my secret function")
# end
#
# end

# %%
push!(LOAD_PATH, pwd())   # Seems like a dirty hack to me 
using mymodule

# %%
mycoolfunction();
mysecretfunction();
# Out:
# this is my cool function
# LoadError: UndefVarError: mysecretfunction not defined
# while loading In[19], in expression starting on line 2

# %%
import mymodule
mymodule.mycoolfunction();
mymodule.mysecretfunction();
# Out:
# this is my cool function
# this is my secret function

# %% [markdown]
# ### Numerical precision
#
# Support for fractions and arbitrary precision numbers (and it gives me the opportunity to brag about fancy unicode support again)

# %%
println("10^18 = ",10^18)
println("10^19 ≂̸ ",10^19)
println("10^19 = ",big(10)^19)
# Out:
# 10^18 = 1000000000000000000
# 10^19 ≂̸ -8446744073709551616
# 10^19 = 10000000000000000000

# %%
c = 1//3
# Out:
# 1//3

# %%
1//3 + 3//8
# Out:
# 17//24

# %% [markdown]
# ## Plotting
#
# You could use matplotlib (as in the slides). The Julia module Pyplot basically implements the pyplot package from matplotlib.

# %%
# Pkg.add("PyPlot")
import PyPlot 
pp = PyPlot

x = linspace(1,10,100)
y = sin(x)

p = pp.plot(x, y, "ro-")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3130342e8>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x315b0fe10>

# %% [markdown]
# ### Gadfly
#
#
# Gadfly is a native Julia plotting package, based on the Grammar of Graphics syntax, and thus with a similar flavour to R's ggplot package. Looks like the package redefines the division function that was defined by the SIUnits package, so you get a warning.

# %%
# Pkg.add("Gadfly")
import Gadfly
gf=Gadfly
# Out:
# WARNING: New definition
#     /(DualNumbers.Dual, Number) at /Users/grange/.julia/v0.4/DualNumbers/src/dual.jl:230
# is ambiguous with:
#     /(Number, SIUnits.SIQuantity{#T<:Any, m<:Any, kg<:Any, s<:Any, A<:Any, K<:Any, mol<:Any, cd<:Any, rad<:Any, sr<:Any}) at /Users/grange/.julia/v0.4/SIUnits/src/SIUnits.jl:156.
# To fix, define
#     /(DualNumbers.Dual, SIUnits.SIQuantity{#T<:Any, m<:Any, kg<:Any, s<:Any, A<:Any, K<:Any, mol<:Any, cd<:Any, rad<:Any, sr<:Any})
# before the new definition.
# WARNING: New definition
#     /(DualNumbers.Dual, Number) at /Users/grange/.julia/v0.4/DualNumbers/src/dual.jl:230
# is ambiguous with:
#     /(Number, SIUnits.SIUnit) at /Users/grange/.julia/v0.4/SIUnits/src/SIUnits.jl:169.
# To fix, define
#     /(DualNumbers.Dual, SIUnits.SIUnit)
# before the new definition.
# Gadfly

# %%
xs = 1:100
ys = cos(xs)

gf.plot(x=xs, y=ys)
# Out:
# Plot(...)

# %% [markdown]
# ### Ccall your own libraries
# Essentially as easy as ccalling installed libraries

# %%
; cat test.c
# Out:
# #include <stdio.h>
#
# void print_a_message( void )
# {
# 	    printf("A STRING: %d\n", 1);
# }

# %%
; gcc -dynamiclib -o test.dylib test.c

# %%
ccall( (:print_a_message, "test"),Void,() )

# %% [markdown]
# ### Introspection
# You can get the compiled version of the code at any level of compilation.

# %%
code_lowered(f, (Int,))
# Out:
# A STRING: 1
# 1-element Array{Any,1}:
#  :($(Expr(:lambda, Any[:x], Any[Any[Any[:x,:Any,0]],Any[],0,Any[]], :(begin  # In[9], line 2:
#         return 2x + 3
#     end))))

# %%
code_typed(f, (Int,))
# Out:
# 1-element Array{Any,1}:
#  :($(Expr(:lambda, Any[:x], Any[Any[Any[:x,Int64,0]],Any[],Any[],Any[]], :(begin  # In[9], line 2:
#         return (Base.box)(Base.Int,(Base.add_int)((Base.box)(Int64,(Base.mul_int)(2,x::Int64)),3))
#     end::Int64))))

# %%
code_llvm(f, (Int,))
# Out:
# define i64 @julia_f_23968(i64) {
# top:
#   %1 = shl i64 %0, 1
#   %2 = add i64 %1, 3
#   ret i64 %2
# }

# %%
code_native(f,(Int,))

# %% [markdown]
# ### Profiling
# I had to show something about profiling of course!

# %%
#Pkg.add("ProfileView")
using ProfileView   # This makes the output a bit more understandable for me...

# %%
function profile_test(n)
    for i = 1:n
        A = randn(100,100,20)
        m = maximum(A)
        Afft = fft(A)
        Am = mapslices(sum, A, 2)
        B = A[:,:,5]
        Bsort = mapslices(sort, B, 1)
        b = rand(100)
        C = B.*b
    end
end

profile_test(1)  # run once to trigger compilation
Profile.clear()  # in case we have any previous profiling data
@profile profile_test(10)

# %%
ProfileView.view()
# Out:
# 	.section	__TEXT,__text,regular,pure_instructions
# Filename: In[9]
# Source line: 2
# 	pushq	%rbp
# 	movq	%rsp, %rbp
# Source line: 2
# 	leaq	3(%rdi,%rdi), %rax
# 	popq	%rbp
# 	ret
# ProfileView.ProfileData(252x11 Array{ColorTypes.RGB{FixedPointNumbers.UFixed{UInt8,8}},2}:
#  RGB{U8}(0.471,0.353,0.988)  …  RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)  …  RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)  …  RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
# ...
